# %% [markdown]
# # matplotlib 파이썬에서 그래프를 그릴 때 사용
# - matplotlib: 기본툴
# - seaborn: matplotlib을 간단하고 예쁘게
# - plotly: 그래프에 동적 요소 포함
# - koreanize_matplotlib: matplotlib, seaborn에서 한글 폰트 자동 설정

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import koreanize_matplotlib

# %% [markdown]
# # 간단한 그래프 예제
# - fig: 전체 그래프가 그려지는 도화지
# - ax: 한 개의 그래프

# %%
fig, ax = plt.subplots()
ax.plot([1, 2, 3, 4], [1, 4, 2, 3])
plt.show()

# %% [markdown]
# # x, y 축이 하나씩 있는 그래프 그리기

# %%
fig, ax = plt.subplots()
plt.show()

# %% [markdown]
# # 2 X 2 4개 그래프 그리기

# %%
fig, ax = plt.subplots(2, 2)
print(ax.shape)
print(ax)
# Out:
# (2, 2)
# [[<Axes: > <Axes: >]
#  [<Axes: > <Axes: >]]

# %% [markdown]
# # 2X3 그래프

# %%
fig, ax = plt.subplots(2, 3)

# %% [markdown]
# # 2X2 그래프에서 왼쪽 행 결합하기
# - plt.subplot_mosaic([['left', 'right_top'], <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;['left', 'right_bottom']])

# %%
fig, ax = plt.subplot_mosaic([['left', 'right_top'],
                             ['left', 'right_bottom']])
plt.show()

# %% [markdown]
# # 2X2 그래프에서 오른쪽 행을 합치고 왼쪽은 2개
# - 합치고 싶은 곳 이름 똑같이 주기, 나머지는 이름 따로

# %%
fig, ax = plt.subplot_mosaic([['left_1', 'right'],
                             ['left_2', 'right']])
plt.show()

# %% [markdown]
# # 2X2 그래프에서 위에만 열을 합치고 아래는 2개

# %%
fig, ax = plt.subplot_mosaic([['top', 'top'],
                             ['left', 'right']])
plt.show()

# %%
fig, ax = plt.subplot_mosaic([['top_l', 'top_r'],
                             ['bottom', 'bottom']])
plt.show()

# %% [markdown]
# # matplotlib의 2가지 코딩 스타일

# %% [markdown]
# ## OO-스타일: matplotlib의 공식 추천 스타일
# - 복잡한 그래프를 그릴 때 사용
# - 사용법이 pyploy 스타일보다 복잡함

# %%
x = np.linspace(0, 2, 100)
x
# Out:
# array([0.        , 0.02020202, 0.04040404, 0.06060606, 0.08080808,
#        0.1010101 , 0.12121212, 0.14141414, 0.16161616, 0.18181818,
#        0.2020202 , 0.22222222, 0.24242424, 0.26262626, 0.28282828,
#        0.3030303 , 0.32323232, 0.34343434, 0.36363636, 0.38383838,
#        0.4040404 , 0.42424242, 0.44444444, 0.46464646, 0.48484848,
#        0.50505051, 0.52525253, 0.54545455, 0.56565657, 0.58585859,
#        0.60606061, 0.62626263, 0.64646465, 0.66666667, 0.68686869,
#        0.70707071, 0.72727273, 0.74747475, 0.76767677, 0.78787879,
#        0.80808081, 0.82828283, 0.84848485, 0.86868687, 0.88888889,
#        0.90909091, 0.92929293, 0.94949495, 0.96969697, 0.98989899,
#        1.01010101, 1.03030303, 1.05050505, 1.07070707, 1.09090909,
#        1.11111111, 1.13131313, 1.15151515, 1.17171717, 1.19191919,
#        1.21212121, 1.23232323, 1.25252525, 1.27272727, 1.29292929,
#        1.31313131, 1.33333333, 1.35353535, 1.37373737, 1.39393939,
# ...

# %%
fig, ax = plt.subplots(figsize=(5, 2.7))
ax.plot(x, x, label='linear')
ax.plot(x, x**2, label='quadratic')
ax.plot(x, x**3, label='cubic')
ax.set_xlabel('x label')
ax.set_ylabel('y label')
ax.legend()  # 범례
ax.set_title('간단 그래프')
# Out:
# Text(0.5, 1.0, '간단 그래프')

# %%
fig, ax = plt.subplots(3, 1, figsize=(5, 7))
print(ax) # 리스트 형태로 들어 있어서 인덱싱 가능
ax[0].plot(x, x, label='linear')
ax[1].plot(x, x**2, label='quadratic')
ax[2].plot(x, x**3, label='cubic')
ax[0].set_xlabel('x label')
ax[0].set_ylabel('y label')
ax[0].set_title('간단 그래프')
ax[1].set_xlabel('x label')
ax[1].set_ylabel('y label')
ax[1].set_title('quadratic 간단 그래프')
ax[2].set_xlabel('x label')
ax[2].set_ylabel('y label')
ax[2].set_title('cubic 간단 그래프')
plt.tight_layout() # 간섭 없이 나오게 하기
plt.show()
# Out:
# [<Axes: > <Axes: > <Axes: >]

# %% [markdown]
# # pyplot 스타일
# - OO-style 보다 사용법 간단
# - 복잡한 그래프를 그릴 때는 적합하지 않다.

# %%
plt.figure(figsize=(5, 2.7))
plt.plot(x, x, label='linear')
plt.plot(x, x**2, label='quadratic')
plt.plot(x, x**3, label='cubic')
plt.xlabel('x label')
plt.ylabel('y label')
plt.legend()  # 범례
plt.title('pyplot 간단 그래프')
plt.show()

# %% [markdown]
# # 선 모양 바꾸기 set_linestyle(모양)

# %%
data1, data2, data3, data4 = np.random.randn(4, 100)

# %% [markdown]
# 선모양 옵션 : '-', '--', '-.', ':'

# %%
fig, ax = plt.subplots(figsize=(5, 2.7))
x = np.arange(len(data1))
ax.plot(x, np.cumsum(data1), color='blue', linewidth=3, linestyle=':')
ax.plot(x, np.cumsum(data2), color='orange', linewidth=2, linestyle='-.')
plt.show()

# %% [markdown]
# # 산점도 그래프를 그리고 색 변경하기
# - facecolor(안쪽색), edgecolor(테두리색)
# - c='색상', edgecolors= 'face'or'색상'
# - s=원의 크기

# %%
fig, ax = plt.subplots(figsize=(5, 2.7))
ax.scatter(data1, data2, s=30, facecolor='c', edgecolor='k')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(5, 2.7))
ax.scatter(data1, data2, s=50, c='c', edgecolor='k')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(5, 2.7))
ax.scatter(data1, data2, s=50, c=(1,0,0), edgecolor=((0,0,0), 0.5))
plt.show()
# Out:
# C:\Users\hello\AppData\Local\Temp\ipykernel_11284\1488386080.py:2: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   ax.scatter(data1, data2, s=50, c=(1,0,0), edgecolor=((0,0,0), 0.5))

# %%
fig, ax = plt.subplots(figsize=(5, 2.7))
ax.scatter(data1, data2, s=50, c=(1,0,0), edgecolor=('k', 0.5))
plt.show()
# Out:
# C:\Users\hello\AppData\Local\Temp\ipykernel_11284\776819503.py:2: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   ax.scatter(data1, data2, s=50, c=(1,0,0), edgecolor=('k', 0.5))

# %% [markdown]
# # 마커의 모양 지정하기
# | 마커 | 설명 |
# |-----|:-----|
# |'.' |        point marker |
# |',' |       pixel marker |
# |'o' |        circle marker|
# |'v' |        triangle_down marker|
# |'^' |        triangle_up marker|
# |'<' |        triangle_left marker|
# |'>' |        triangle_right marker|
# |'1' |        tri_down marker|
# |'2' |        tri_up marker|
# |'3' |        tri_left marker|
# |'4' |        tri_right marker|
# |'8' |        octagon marker|
# |'s' |        square marker|
# |'p' |        pentagon marker|
# |'P' |        plus (filled) marker|
# |'*' |        star marker|
# |'h' |        hexagon1 marker|
# |'H' |        hexagon2 marker|
# |'+' |        plus marker|
# |'x' |        x marker|
# |'X' |        x (filled) marker|
# |'D' |        diamond marker|
# |'d' |        thindiamond marker|
# |'|' |        vline marker|
# |'_' |        hline marker|

# %%
fig, ax = plt.subplots(figsize=(5, 4))
ax.plot(data1, '8', label='data1')
ax.plot(data2, 'D', label='data2')
ax.plot(data3, 'x', label='data3')
ax.plot(data4, '>', label='data4')
ax.legend()
plt.show()

# %% [markdown]
# # x축, y축 이름, 눈금, 그래프 이름

# %%
mu, sigma = 115, 15
x = mu + sigma*np.random.randn(10000)
fig, ax = plt.subplots(figsize=(5, 2.7))
n, bins, patches = ax.hist(x, 50, density=True, color='C0', alpha=0.75)
ax.set_xlabel('Length [cm]')
ax.set_ylabel('Probability')
ax.set_title('Aardvark lengths \n (not really)')
ax.text(75, 0.025, r'$\mu=115, \ \sigma=15$')
ax.axis([60, 160, 0, 0.03])  # [x축시작, x축끝 범위, y축 시작, y축 끝 범위]
plt.show()

# %% [markdown]
# # 눈금자 단위 구간 설정하기

# %%
xdata = np.arange(len(data1))
# 최근에는 tight잘 안 쓰고 layout='constrained 많이 씀'
# 눈금 자동 지정
fig, ax = plt.subplots(2, 1, figsize=(5, 2.7), layout='constrained')
ax[0].plot(xdata, data1)
ax[0].set_title('automatic ticks')

# 눈금 지정
ax[1].plot(xdata, data2)
ax[1].set_xticks(np.arange(0, 100, 30), ['zero', '30', 'sixty', '90'])
ax[1].set_yticks([-1.5, 0, 1.5])
ax[1].set_title('manual ticks')

plt.show()

# %% [markdown]
# # 카테고리 막대 그래프 그리기

# %%
fig, ax = plt.subplots(figsize=(5, 2.7))
categories = ['turnips', 'rutabaga', 'cucumber', 'pumpkins']
ax.bar(categories, np.random.rand(len(categories)))
plt.show()
